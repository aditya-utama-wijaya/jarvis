# %%
from warnings import filterwarnings
filterwarnings('ignore')

import pandas as pd
pd.set_option('display.max_columns', None)

path = 'data/'

# %%
bitmex = pd.read_csv(path + 'bitmex_orderbooks.csv')
print(bitmex.shape)
pd.concat([bitmex.head(), bitmex.tail()])
# Out:
# (341272, 45)
#         {"_id":{"$oid":"5ea05352a4962f0b53b015a3"}  exchange:"Bitmex"  \
# 0       {"_id":{"$oid":"5ea05352a4962f0b53b015a6"}  exchange:"Bitmex"
# 1       {"_id":{"$oid":"5ea05352a4962f0b53b015a7"}  exchange:"Bitmex"
# 2       {"_id":{"$oid":"5ea05352a4962f0b53b015b1"}  exchange:"Bitmex"
# 3       {"_id":{"$oid":"5ea05352a4962f0b53b01616"}  exchange:"Bitmex"
# 4       {"_id":{"$oid":"5ea05352a4962f0b53b0161b"}  exchange:"Bitmex"
# 341267  {"_id":{"$oid":"5ea124204215375fef446bb3"}  exchange:"Bitmex"
# 341268  {"_id":{"$oid":"5ea124204215375fef446bb4"}  exchange:"Bitmex"
# 341269  {"_id":{"$oid":"5ea124204215375fef446bb5"}  exchange:"Bitmex"
# 341270  {"_id":{"$oid":"5ea124204215375fef446bb6"}  exchange:"Bitmex"
# 341271  {"_id":{"$oid":"5ea124204215375fef446bb7"}  exchange:"Bitmex"
#
#         symbol:"BTC_PERPETUAL"  bids:[[7077.5  2274827]    [7077  24571]  \
# 0       symbol:"BTC_PERPETUAL"  bids:[[7077.5  2276398]    [7077  24571]
# ...
